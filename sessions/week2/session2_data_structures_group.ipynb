# %% [markdown]
# # Week 2 — Group Session: Data Structures

# %% [markdown]
# ## Objectives- Collaborate on list and dictionary tasks.- Practice set operations for data cleaning.- Apply file handling in a quick exercise.

# %% [markdown]
# ### Activity 1: Deduplicate with Sets

# %% [markdown]
# Create a function `dedupe(items)` that returns a list of unique items, preserving any reasonable order.

# %%
def dedupe(items):    return list(set(items))print(dedupe(['a','b','a','c','b']))

# %% [markdown]
# ### Activity 2: Merge Dictionaries

# %% [markdown]
# Write `merge_dicts(a, b)` that returns a merged dictionary. If keys overlap, values from `b` should take precedence.

# %%
def merge_dicts(a, b):    result = a.copy()    result.update(b)    return resultprint(merge_dicts({'x':1,'y':2},{'y':3,'z':4}))

# %% [markdown]
# ### Activity 3: List Slicing and Mapping

# %% [markdown]
# Given a list of numbers, create a new list containing the squares of the last five numbers.

# %%
nums = list(range(1, 21))tail = nums[-5:]squares = list(map(lambda x: x*x, tail))print(squares)

# %% [markdown]
# ### Activity 4: Quick File HandlingWrite a function that reads all lines from `group_example.txt` and returns only the lines with more than 10 characters.

# %%
with open('group_example.txt', 'w') as f:    f.write('short')    f.write('
this line is long enough')def long_lines(path):    with open(path, 'r') as f:        lines = f.readlines()    return [line.strip() for line in lines if len(line.strip()) > 10]print(long_lines('group_example.txt'))

# %% [markdown]
# ### Collaboration GuideAssign roles and rotate: Driver writes code, Navigator reviews logic, Tester designs inputs.

# %% [markdown]
# ### RecapDiscuss trade-offs of sets for deduplication, dictionary merging strategies, and map vs comprehensions.
