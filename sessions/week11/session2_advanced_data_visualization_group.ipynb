# %% [markdown]
# # Week 11 — Group Session: Advanced Data Visualization Techniques

# %% [markdown]
# ## Objectives- Collaborate on multi-series and annotated charts.- Ensure clarity with legends and labels.- Provide text fallbacks when plotting libs are unavailable.

# %% [markdown]
# ### Activity 1: Multi-Series Plot

# %%
series = {'A':[1,2,3], 'B':[2,3,1], 'C':[3,1,2]}try:    import matplotlib.pyplot as plt    for name, values in series.items():        plt.plot(values, label=name)    plt.legend()    plt.title('Three Series')    plt.show()except Exception:    for name, values in series.items():        print(name, values)

# %% [markdown]
# **Task:** Add axis labels and annotate the max value across all series.

# %%
pass

# %% [markdown]
# ### Activity 2: Scatter with Categories

# %%
points = [(1,2,'A'),(2,2,'B'),(3,4,'A'),(4,3,'B')]try:    import matplotlib.pyplot as plt    xsA = [x for x,y,c in points if c=='A']    ysA = [y for x,y,c in points if c=='A']    xsB = [x for x,y,c in points if c=='B']    ysB = [y for x,y,c in points if c=='B']    plt.scatter(xsA, ysA, label='A')    plt.scatter(xsB, ysB, label='B')    plt.legend()    plt.title('Categorized Scatter')    plt.show()except Exception:    print(points)

# %% [markdown]
# **Task:** Compute average Y per category and annotate centers.

# %%
pass

# %% [markdown]
# ### Collaboration GuideRoles: Designer, Implementer, Reviewer; rotate per activity.
