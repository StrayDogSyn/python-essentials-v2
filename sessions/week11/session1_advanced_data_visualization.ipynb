# %% [markdown]
# # Week 11 — Advanced Data Visualization Techniques

# %% [markdown]
# ## Objectives- Create multi-series charts if libraries are available.- Use graceful fallbacks for environments without plotting libs.- Focus on labeling and readability.

# %% [markdown]
# ### Multiple Series Line Chart (Optional)

# %%
series1 = [1,2,3,4,5]series2 = [2,1,4,3,6]try:    import matplotlib.pyplot as plt    plt.plot(series1, label='Series 1')    plt.plot(series2, label='Series 2')    plt.legend()    plt.title('Two Series')    plt.show()except Exception:    print(series1)    print(series2)

# %% [markdown]
# **Activity:** Plot three series with labels and legend; fallback prints each series.

# %%
pass

# %% [markdown]
# ### Scatter Plot (Optional)

# %%
xs = [1,2,3,4]ys = [2,3,2,5]try:    import matplotlib.pyplot as plt    plt.scatter(xs, ys)    plt.title('Scatter Example')    plt.xlabel('X')    plt.ylabel('Y')    plt.show()except Exception:    print(list(zip(xs, ys)))

# %% [markdown]
# **Activity:** Add annotations for the max Y point; fallback prints tuple and index.

# %%
pass

# %% [markdown]
# ### RecapAdvanced charts benefit from clear labels and legends; fallbacks maintain interpretability.
