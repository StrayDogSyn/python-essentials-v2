# %% [markdown]
# # Week 7 — Group Session: Introduction to Data Visualization

# %% [markdown]
# ## Objectives- Choose chart types for given data.- Implement plotting with graceful fallback.- Review clarity and labeling.

# %% [markdown]
# ### Activity 1: Category Counts

# %%
data = {'cats':4,'dogs':6,'birds':2}try:    import matplotlib.pyplot as plt    plt.bar(list(data.keys()), list(data.values()))    plt.title('Pets')    plt.xlabel('Type')    plt.ylabel('Count')    plt.show()except Exception:    for k,v in data.items():        print(k + ' ' + ('#'*v))

# %% [markdown]
# **Task:** Add labels and ensure counts are accurate; discuss which chart is best.

# %%
pass

# %% [markdown]
# ### Activity 2: Time Series

# %%
series = [70,72,69,75,73]try:    import matplotlib.pyplot as plt    plt.plot(series)    plt.title('Temperature Week')    plt.xlabel('Day')    plt.ylabel('Temp')    plt.show()except Exception:    print(series)

# %% [markdown]
# **Task:** Annotate the max value; fallback prints the index and value.

# %%
pass

# %% [markdown]
# ### Collaboration GuideRoles: Designer (choose chart), Implementer (code), Reviewer (labels/clarity).
