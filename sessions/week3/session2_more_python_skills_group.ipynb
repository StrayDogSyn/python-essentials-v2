# %% [markdown]
# # Week 3 — Group Session: More Python Skills

# %% [markdown]
# ## Objectives- Refactor imperative loops into comprehensions.- Design robust exception handling.- Collaborate on writing generators and simple modules.

# %% [markdown]
# ### Activity 1: Refactor to Comprehensions

# %%
data = ['apple','banana','kiwi','pear','grape']filtered = []for item in data:    if len(item) > 4:        filtered.append(item.upper())print(filtered)

# %% [markdown]
# **Task:** Produce an equivalent result using a single list comprehension.

# %%
pass

# %% [markdown]
# ### Activity 2: Resilient Exception Handling

# %%
inputs = ['10','x','25']results = []for s in inputs:    try:        results.append(int(s))    except Exception as e:        results.append(None)print(results)

# %% [markdown]
# **Task:** Replace `None` with a default value of `0` and count how many conversions failed.

# %%
pass

# %% [markdown]
# ### Activity 3: Generators and Modules

# %%
def words_longer_than(words, n):    for w in words:        if len(w) > n:            yield wprint(list(words_longer_than(['this','session','rocks'], 4)))

# %% [markdown]
# **Task:** Move the generator into a separate cell and simulate importing it with `from __main__ import words_longer_than` in a new cell, then call it.

# %%
pass

# %% [markdown]
# ### Collaboration GuideAssign roles: Driver implements, Navigator reviews and suggests refactors, Tester designs inputs and edge cases.
