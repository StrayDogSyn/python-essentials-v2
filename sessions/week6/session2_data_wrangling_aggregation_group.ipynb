# %% [markdown]
# # Week 6 — Group Session: Data Wrangling and Aggregation

# %% [markdown]
# ## Objectives- Collaborate on grouping and summarization.- Build small pure-Python aggregations.- Compare approaches for clarity and efficiency.

# %% [markdown]
# ### Activity 1: Group by Dept

# %%
records = [{'dept':'A','score':10},{'dept':'B','score':20},{'dept':'A','score':30},{'dept':'B','score':25}]groups = {}for r in records:    groups.setdefault(r['dept'], []).append(r['score'])print(groups)

# %% [markdown]
# **Task:** Compute average per dept and return a summary dictionary.

# %%
pass

# %% [markdown]
# ### Activity 2: Top N by Dept

# %%
summary = {k:sorted(v, reverse=True)[:2] for k,v in groups.items()}print(summary)

# %% [markdown]
# **Task:** Generalize to a function `top_n(groups, n)` returning top `n` per key.

# %%
pass

# %% [markdown]
# ### Collaboration GuideRoles: Grouper, Aggregator, Reviewer; rotate after each activity.
